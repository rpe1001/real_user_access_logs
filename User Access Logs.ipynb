# %%
import pandas as pd
df_employees=pd.read_csv('data/employees.csv')
df_system_access=pd.read_csv('data/system_access.csv')

# %%
df_system_access['id'] = 'EMP' + df_system_access['id'].astype(str).str.zfill(6)
df_system_access.head()
# Out:
#           id    access_level
# 0  EMP017263   Account Admin
# 1  EMP010275  Contract Entry
# 2  EMP007568  Contract Entry
# 3  EMP021986   Account Admin
# 4  EMP020614   Account Admin

# %%
df_employees.head()
# Out:
#   employee_number first_name last_name                             email  \
# 0       EMP003037    Juliana  Burbudge  juliana.burbudge@consultants.com
# 1       EMP003045     Lizzie      Blue       lizzie.blue@consultants.com
# 2       EMP003051    Marjory  Selcraig  marjory.selcraig@consultants.com
# 3       EMP003068     Aguste  O'Connor   aguste.o'connor@consultants.com
# 4       EMP003097    Clemens    Kopman    clemens.kopman@consultants.com
#
#                title
# 0  Director of Sales
# 1    Sales Assistant
# 2    Sales Assistant
# 3    Sales Assistant
# 4    Account Manager

# %%
df_system_access.rename(columns={'id':'employee_number'},inplace=True)
df_system_access.head()
# Out:
#                    access_level
# employee_number
# EMP017263         Account Admin
# EMP010275        Contract Entry
# EMP007568        Contract Entry
# EMP021986         Account Admin
# EMP020614         Account Admin

# %%
df = df_employees.join(df_system_access, how='left')
df
# Out:
#      employee_number  first_name   last_name  \
# 0          EMP003037     Juliana    Burbudge
# 1          EMP003045      Lizzie        Blue
# 2          EMP003051     Marjory    Selcraig
# 3          EMP003068      Aguste    O'Connor
# 4          EMP003097     Clemens      Kopman
# ...              ...         ...         ...
# 1115       EMP024864    Kristina       Yakov
# 1116       EMP024885   Margarita  Habbergham
# 1117       EMP024890    Prescott   Southward
# 1118       EMP024896       Raine     Learned
# 1119       EMP024931  Frederique        Fant
#
#                                      email              title access_level
# 0         juliana.burbudge@consultants.com  Director of Sales          NaN
# 1              lizzie.blue@consultants.com    Sales Assistant          NaN
# 2         marjory.selcraig@consultants.com    Sales Assistant          NaN
# 3          aguste.o'connor@consultants.com    Sales Assistant          NaN
# 4           clemens.kopman@consultants.com    Account Manager          NaN
# ...                                    ...                ...          ...
# 1115        kristina.yakov@consultants.com    Sales Assistant          NaN
# 1116  margarita.habbergham@consultants.com    Account Manager          NaN
# 1117    prescott.southward@consultants.com    Account Manager          NaN
# 1118         raine.learned@consultants.com    Account Manager          NaN
# 1119       frederique.fant@consultants.com    Sales Assistant          NaN
#
# [1120 rows x 6 columns]
